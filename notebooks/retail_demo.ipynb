# %% [markdown]
# # EvoMind Retail DemoQuick notebook showing how to prepare the retail dataset with the EvoMind adapters.

# %%
from pathlib import Pathfrom core.config_loader import ConfigLoaderfrom main import build_adapter, prepare_datasetloader = ConfigLoader(Path("configs/global.yaml"))config = loader.load(Path("configs/retail.yaml")).to_dict()adapter = build_adapter("forecasting")dataset = prepare_dataset(adapter, Path("data/holiday_sales.csv"))print("Prepared dataset shapes:", [arr.shape for arr in dataset])
